# %%
import pandas as pd

# %%
#!pip install pyodbc

# %%
import cx_Oracle
import pyodbc
#jdbc:oracle:thin:@alintvisp:1521:intvisp

# %%
dsn = cx_Oracle.makedsn("alintvisp", 1521, sid="intvisp")
connection = cx_Oracle.connect(user="sraut", password='Ash#1234pinkdrap', dsn=dsn,
                               encoding="UTF-8")

# %%
cursor = connection.cursor()
#cursor.close()
#connection.close()

# %%
cursor.execute("select * from visibility.raptor2_transaction FETCH FIRST 10 ROWS ONLY")
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to sraut@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=alintvisp)(PORT=1521))(CONNECT_DATA=(SID=intvisp)))>>

# %%
cursor.fetchone()
# Out:
# (130860183005,
#  'NestleOsem',
#  None,
#  'GEONESTLEOSEM',
#  '9021010017',
#  '945',
#  'OUTBOUND',
#  'SENT',
#  'ACKNOWLEDGED',
#  'SI',
#  '000016070',
#  '2359',
#  1042025362,
#  1,
#  'OSEM USA, INC_SYNAPSE_945_IEV2_18313_bc62994c24da473.RDY',
#  '\\\\FDC00GISA640L\\raptor\\2022\\09\\28',
#  5,
#  1042025665,
#  1,
#  'GEODIS_NESTLEOSEM_945_20220928074324_1822780600.txt',
#  '\\\\FDC00GISA640L\\raptor\\2022\\09\\28',
#  5,
#  '400104593',
#  'N/A',
#  'N/A',
#  datetime.datetime(2022, 9, 28, 7, 41, 27),
#  datetime.datetime(2023, 4, 28, 5, 40, 39),
#  datetime.datetime(2023, 4, 28, 14, 59, 10),
#  datetime.datetime(2023, 4, 28, 14, 59, 10))

# %%
query = "select * from visibility.raptor2_transaction FETCH FIRST 10 ROWS ONLY"
df = pd.read_sql(query, con=connection)
df
# Out:
# C:\Users\aa-skrishna\AppData\Local\Temp\3\ipykernel_7612\601275672.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con=connection)
#    TRANSACTION_ID TP_NAME CUSTOMER_ID      SENDER      RECEIVER DOC_CODE  \
# 0    143325255905    None        None  OHL-APPLE2  060704780501      856
# 1    143325256305    None        None  OHL-APPLE2  060704780501      856
# 2    143325256705    None        None  OHL-APPLE2  060704780501      856
# 3    143325257905    None        None  OHL-APPLE2  060704780501      856
# 4    143325258305    None        None  OHL-APPLE2  060704780501      856
# 5    143325253805    None        None  OHL-APPLE2  060704780501      856
# 6    143325254205    None        None  OHL-APPLE2  060704780501      856
# 7    143325254505    None        None  OHL-APPLE2  060704780501      856
# ...

# %%
import pyspark

# %%
# !python -m pip install findspark
# Out:
# ...
#   Using cached findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# ...

# %%
import findspark
findspark.init()

import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

df = spark.sql("select 'spark' as hello")
df.show()
# Out:
# +-----+
# |hello|
# +-----+
# |spark|
# +-----+
